# %% [markdown]
# @author Nassir Mohammad
#
# # Preliminaries

# %%
import os
import sys 
sys.path.append('../scripts')

import warnings
from PerceptionAlgorithm import Perception

import dataframe_image as dfi

import numpy as np
import pandas as pd

from utilities import apply_classifiers
from utilities import get_file_data

from sklearn.preprocessing import StandardScaler
from rendering_functions import highlight_max, highlight_min

image_save_path = ''
image_save_switch = False

# %% [markdown]
# # Paper 1 datasets

# %%
# make table for dataset, # dimensions, # samples, # percentage of anomalies

base_path = "../data/ODDS_multivariate/"
data_properties_df = None

# loop over datasets in directory
for file_name in os.listdir(base_path):

    dataset_name, X_original, y = get_file_data(base_path, file_name)

    if dataset_name is None:
        continue

    # write dataset summary to dataframe
    data_properties_temp = pd.DataFrame({
        'Name': [dataset_name],
        '\# examples': [X_original.shape[0]],
        '\# features': [X_original.shape[1]],
        # '# anomalies': [y.sum()],
        '\% anomalies': [float(np.round(y.sum()/X_original.shape[0]*100, 2))],
    })

    data_properties_df = pd.concat(
        [data_properties_df, data_properties_temp]).reset_index(drop=True)

# %%
img_title = "Dataset properties"
path_save = image_save_path + "dataset_properties.png"

# order the dataset rows by name
data_properties_df = data_properties_df.sort_values(by=['Name']).reset_index(drop=True)

data_properties_df_styled = data_properties_df.style.format({'\% anomalies': "{:.2f}"}).hide_index()

#data_properties_df_styled = data_properties_df.style.hide_index()

#dfi.export(data_properties_df,path_save)

data_properties_df_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_88dc1_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >\# examples</th>
#       <th class="col_heading level0 col2" >\# features</th>
#       <th class="col_heading level0 col3" >\% anomalies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_88dc1_row0_col0" class="data row0 col0" >cardio</td>
#       <td id="T_88dc1_row0_col1" class="data row0 col1" >1831</td>
#       <td id="T_88dc1_row0_col2" class="data row0 col2" >21</td>
#       <td id="T_88dc1_row0_col3" class="data row0 col3" >9.61</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row1_col0" class="data row1 col0" >credit-card</td>
#       <td id="T_88dc1_row1_col1" class="data row1 col1" >284807</td>
#       <td id="T_88dc1_row1_col2" class="data row1 col2" >29</td>
#       <td id="T_88dc1_row1_col3" class="data row1 col3" >0.17</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row2_col0" class="data row2 col0" >http</td>
#       <td id="T_88dc1_row2_col1" class="data row2 col1" >567498</td>
#       <td id="T_88dc1_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_88dc1_row2_col3" class="data row2 col3" >0.39</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row3_col0" class="data row3 col0" >musk</td>
#       <td id="T_88dc1_row3_col1" class="data row3 col1" >3062</td>
#       <td id="T_88dc1_row3_col2" class="data row3 col2" >166</td>
#       <td id="T_88dc1_row3_col3" class="data row3 col3" >3.17</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row4_col0" class="data row4 col0" >satimage-2</td>
#       <td id="T_88dc1_row4_col1" class="data row4 col1" >5803</td>
#       <td id="T_88dc1_row4_col2" class="data row4 col2" >36</td>
#       <td id="T_88dc1_row4_col3" class="data row4 col3" >1.22</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row5_col0" class="data row5 col0" >shuttle</td>
#       <td id="T_88dc1_row5_col1" class="data row5 col1" >49097</td>
#       <td id="T_88dc1_row5_col2" class="data row5 col2" >9</td>
#       <td id="T_88dc1_row5_col3" class="data row5 col3" >7.15</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row6_col0" class="data row6 col0" >smtp</td>
#       <td id="T_88dc1_row6_col1" class="data row6 col1" >95156</td>
#       <td id="T_88dc1_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_88dc1_row6_col3" class="data row6 col3" >0.03</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row7_col0" class="data row7 col0" >thyroid</td>
#       <td id="T_88dc1_row7_col1" class="data row7 col1" >3772</td>
#       <td id="T_88dc1_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_88dc1_row7_col3" class="data row7 col3" >2.47</td>
#     </tr>
#     <tr>
#       <td id="T_88dc1_row8_col0" class="data row8 col0" >wbc</td>
#       <td id="T_88dc1_row8_col1" class="data row8 col1" >378</td>
#       <td id="T_88dc1_row8_col2" class="data row8 col2" >30</td>
#       <td id="T_88dc1_row8_col3" class="data row8 col3" >5.56</td>
#     </tr>
#   </tbody>
# </table>

# %%
# file names
# ########################
# file_name = "wbc.mat" 
# file_name = "cardio.mat"
# file_name = "thyroid.mat"
# file_name = "musk.mat"
# file_name = "shuttle.mat"
# file_name = "satimage-2.mat"
# file_name = "http.matv7"
# file_name = "smtp.matv7"
# file_name = "credit-card.csv"

classifiers = [
    'HBOS',  # to be ignored, first run in loop slower
    'HBOS',
    'IForest',
    'KNN',
    'LOF',
    'MCD',
    'OCSVM',
    'Perception',
]

metrics_df = None

with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    # loop over datasets in directory
    for file_name in os.listdir(base_path):

        dataset_name, X_original, y = get_file_data(base_path, file_name)

        if dataset_name is None:
            continue

        # scaling (very important to get right)
        # scale to zero mean and unit standard deviation along each feature
        sc = StandardScaler(with_mean=False)
        sc.fit(X_original)
        X = sc.transform(X_original)

        # Apply each classifier to dataset
        with warnings.catch_warnings():
            warnings.simplefilter('ignore')

            print('current file in progress ...: {}'.format(dataset_name))

            metrics_temp = apply_classifiers(classifiers, dataset_name,
                                             predict_data=X,
                                             predict_labels=y,
                                             train_data=X)

        metrics_df =\
            pd.concat([metrics_df, metrics_temp])

    metrics_df.reset_index(drop=True)
# Out:
# current file in progress ...: credit-card
# current classifier in progress: HBOS
# time: 1.4919238919999884
# current classifier in progress: HBOS
# time: 0.23271063199999276
# current classifier in progress: IForest
# time: 18.568417248000003
# current classifier in progress: KNN
# current classifier in progress: LOF
# current classifier in progress: MCD
# time: 34.068641791000005
# current classifier in progress: OCSVM
# current classifier in progress: Perception
# time: 0.37096926499998517
# current file in progress ...: cardio
# current classifier in progress: HBOS
# time: 0.006678477999997767
# current classifier in progress: HBOS
# time: 0.0060919210000065505
# current classifier in progress: IForest
# time: 0.25206052300001147
# current classifier in progress: KNN
# time: 0.057625674999997045
# current classifier in progress: LOF
# time: 0.05081681199999366
# current classifier in progress: MCD
# time: 0.472412807000012
# current classifier in progress: OCSVM
# time: 0.28290890899998544
# current classifier in progress: Perception
# time: 0.002055848000026117
# current file in progress ...: shuttle
# current classifier in progress: HBOS
# time: 0.013202458000023398
# current classifier in progress: HBOS
# time: 0.012457288000007338
# current classifier in progress: IForest
# time: 2.383925222000016
# current classifier in progress: KNN
# time: 4.01472331399998
# current classifier in progress: LOF
# time: 8.107811593999998
# current classifier in progress: MCD
# time: 14.938943524999985
# current classifier in progress: OCSVM
# time: 197.24415067100003
# current classifier in progress: Perception
# time: 0.04409405599994898
# current file in progress ...: musk
# current classifier in progress: HBOS
# time: 0.04331530000001749
# current classifier in progress: HBOS
# time: 0.04250869700001658
# current classifier in progress: IForest
# time: 0.6932891950000339
# current classifier in progress: KNN
# time: 0.1748345400000062
# current classifier in progress: LOF
# time: 0.141486953000026
# current classifier in progress: MCD
# time: 7.155057929999998
# current classifier in progress: OCSVM
# time: 1.023312601999919
# current classifier in progress: Perception
# time: 0.008825023999975201
# current file in progress ...: http
# current classifier in progress: HBOS
# time: 0.056875523000030626
# current classifier in progress: HBOS
# time: 0.06478884699993159
# current classifier in progress: IForest
# time: 23.317903814000033
# current classifier in progress: KNN
# time: 7.891814101999898
# current classifier in progress: LOF
# time: 10.48716510700001
# current classifier in progress: MCD
# time: 41.32176340800004
# current classifier in progress: OCSVM
# current classifier in progress: Perception
# time: 0.5074690389999432
# current file in progress ...: smtp
# current classifier in progress: HBOS
# time: 0.01242759699994167
# current classifier in progress: HBOS
# time: 0.017870991999984653
# current classifier in progress: IForest
# time: 4.391381403999958
# current classifier in progress: KNN
# time: 0.5170946599999979
# current classifier in progress: LOF
# time: 0.8628221929999427
# current classifier in progress: MCD
# time: 15.811476540000058
# current classifier in progress: OCSVM
# time: 775.9217492540001
# current classifier in progress: Perception
# time: 0.08405737600014618
# current file in progress ...: thyroid
# current classifier in progress: HBOS
# time: 0.0029107420000400452
# current classifier in progress: HBOS
# time: 0.0025409580002815346
# current classifier in progress: IForest
# time: 0.3856201290000172
# current classifier in progress: KNN
# time: 0.05172284399986893
# current classifier in progress: LOF
# time: 0.09420475500019165
# current classifier in progress: MCD
# time: 1.0648482669998884
# current classifier in progress: OCSVM
# time: 0.936213048999889
# current classifier in progress: Perception
# time: 0.0034938819999297266
# current file in progress ...: wbc
# current classifier in progress: HBOS
# time: 0.006390350999936345
# current classifier in progress: HBOS
# time: 0.006290746000104264
# current classifier in progress: IForest
# time: 0.15857725299974845
# current classifier in progress: KNN
# time: 0.0028420140001799155
# current classifier in progress: LOF
# time: 0.006552062999617192
# current classifier in progress: MCD
# time: 0.14265156200008278
# current classifier in progress: OCSVM
# time: 0.011651811999854544
# current classifier in progress: Perception
# time: 0.0012388329996610992
# current file in progress ...: satimage-2
# current classifier in progress: HBOS
# time: 0.032703465999929904
# current classifier in progress: HBOS
# time: 0.01437451299989334
# current classifier in progress: IForest
# time: 0.6192121320000297
# current classifier in progress: KNN
# time: 0.6150044190003428
# current classifier in progress: LOF
# time: 0.47861787300007563
# current classifier in progress: MCD
# time: 2.497732987999825
# current classifier in progress: OCSVM
# time: 3.201814838000246
# current classifier in progress: Perception
# time: 0.006901388999722258

# %%
# create dataframe for precision
df_precision = metrics_df[['Dataset', 'Classifier', 'Precision']]
df_precision = pd.pivot_table(df_precision, values = 'Precision', index=['Classifier'], columns='Dataset').reset_index()
df_precision.columns.name = None

cols = [col for col in df_precision.columns]
formatdict = {}
for col in cols: formatdict[col] = "{:.3f}"
formatdict.pop('Classifier', None)

sub = df_precision.columns.values.tolist()
sub.remove('Classifier')
sub

df_precision = df_precision.style.hide_index().apply(highlight_max, subset=sub).format(formatdict)

# img_title = "Precision results"
# path_save = image_save_path + "dataset_precision.png"

# dfi.export(df_precision,path_save)

df_precision
# Out:
# <style type="text/css">
# #T_8c0ec_row6_col1, #T_8c0ec_row6_col2, #T_8c0ec_row6_col3, #T_8c0ec_row6_col4, #T_8c0ec_row6_col5, #T_8c0ec_row6_col6, #T_8c0ec_row6_col7, #T_8c0ec_row6_col8, #T_8c0ec_row6_col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8c0ec_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Classifier</th>
#       <th class="col_heading level0 col1" >cardio</th>
#       <th class="col_heading level0 col2" >credit-card</th>
#       <th class="col_heading level0 col3" >http</th>
#       <th class="col_heading level0 col4" >musk</th>
#       <th class="col_heading level0 col5" >satimage-2</th>
#       <th class="col_heading level0 col6" >shuttle</th>
#       <th class="col_heading level0 col7" >smtp</th>
#       <th class="col_heading level0 col8" >thyroid</th>
#       <th class="col_heading level0 col9" >wbc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c0ec_row0_col0" class="data row0 col0" >HBOS</td>
#       <td id="T_8c0ec_row0_col1" class="data row0 col1" >0.443</td>
#       <td id="T_8c0ec_row0_col2" class="data row0 col2" >0.015</td>
#       <td id="T_8c0ec_row0_col3" class="data row0 col3" >0.051</td>
#       <td id="T_8c0ec_row0_col4" class="data row0 col4" >0.316</td>
#       <td id="T_8c0ec_row0_col5" class="data row0 col5" >0.114</td>
#       <td id="T_8c0ec_row0_col6" class="data row0 col6" >0.689</td>
#       <td id="T_8c0ec_row0_col7" class="data row0 col7" >0.003</td>
#       <td id="T_8c0ec_row0_col8" class="data row0 col8" >0.202</td>
#       <td id="T_8c0ec_row0_col9" class="data row0 col9" >0.421</td>
#     </tr>
#     <tr>
#       <td id="T_8c0ec_row1_col0" class="data row1 col0" >IForest</td>
#       <td id="T_8c0ec_row1_col1" class="data row1 col1" >0.492</td>
#       <td id="T_8c0ec_row1_col2" class="data row1 col2" >0.015</td>
#       <td id="T_8c0ec_row1_col3" class="data row1 col3" >0.039</td>
#       <td id="T_8c0ec_row1_col4" class="data row1 col4" >0.316</td>
#       <td id="T_8c0ec_row1_col5" class="data row1 col5" >0.120</td>
#       <td id="T_8c0ec_row1_col6" class="data row1 col6" >0.703</td>
#       <td id="T_8c0ec_row1_col7" class="data row1 col7" >0.002</td>
#       <td id="T_8c0ec_row1_col8" class="data row1 col8" >0.233</td>
#       <td id="T_8c0ec_row1_col9" class="data row1 col9" >0.368</td>
#     </tr>
#     <tr>
#       <td id="T_8c0ec_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T_8c0ec_row2_col1" class="data row2 col1" >0.350</td>
#       <td id="T_8c0ec_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T
td>
#     </tr>
#   </tbody>
# </table>

# %%
# create dataframe for recall
df_recall = metrics_df[['Dataset', 'Classifier', 'Recall']]
df_recall = pd.pivot_table(df_recall, values = 'Recall', index=['Classifier'], columns='Dataset').reset_index()
df_recall.columns.name = None

cols = [col for col in df_recall.columns]
formatdict = {}
for col in cols: formatdict[col] = "{:.2f}"
formatdict.pop('Classifier', None)

sub = df_recall.columns.values.tolist()
sub.remove('Classifier')
sub

df_recall = df_recall.style.hide_index().apply(highlight_max, subset=sub).format(formatdict)

img_title = "Recall results"
path_save = image_save_path + "dataset_recall.png"

# dfi.export(df_recall,path_save)

df_recall
# Out:
# <style type="text/css">
# #T_dafcc_row0_col3, #T_dafcc_row0_col4, #T_dafcc_row0_col9, #T_dafcc_row1_col2, #T_dafcc_row1_col3, #T_dafcc_row1_col4, #T_dafcc_row1_col6, #T_dafcc_row1_col7, #T_dafcc_row4_col3, #T_dafcc_row4_col4, #T_dafcc_row4_col5, #T_dafcc_row4_col7, #T_dafcc_row4_col8, #T_dafcc_row5_col1, #T_dafcc_row5_col4, #T_dafcc_row5_col7, #T_dafcc_row6_col3, #T_dafcc_row6_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_dafcc_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Classifier</th>
#       <th class="col_heading level0 col1" >cardio</th>
#       <th class="col_heading level0 col2" >credit-card</th>
#       <th class="col_heading level0 col3" >http</th>
#       <th class="col_heading level0 col4" >musk</th>
#       <th class="col_heading level0 col5" >satimage-2</th>
#       <th class="col_heading level0 col6" >shuttle</th>
#       <th class="col_heading level0 col7" >smtp</th>
#       <th class="col_heading level0 col8" >thyroid</th>
#       <th class="col_heading level0 col9" >wbc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dafcc_row0_col0" class="data row0 col0" >HBOS</td>
#       <td id="T_dafcc_row0_col1" class="data row0 col1" >0.46</td>
#       <td id="T_dafcc_row0_col2" class="data row0 col2" >0.89</td>
#       <td id="T_dafcc_row0_col3" class="data row0 col3" >1.00</td>
#       <td id="T_dafcc_row0_col4" class="data row0 col4" >1.00</td>
#       <td id="T_dafcc_row0_col5" class="data row0 col5" >0.93</td>
#       <td id="T_dafcc_row0_col6" class="data row0 col6" >0.96</td>
#       <td id="T_dafcc_row0_col7" class="data row0 col7" >0.70</td>
#       <td id="T_dafcc_row0_col8" class="data row0 col8" >0.82</td>
#       <td id="T_dafcc_row0_col9" class="data row0 col9" >0.76</td>
#     </tr>
#     <tr>
#       <td id="T_dafcc_row1_col0" class="data row1 col0" >IForest</td>
#       <td id="T_dafcc_row1_col1" class="data row1 col1" >0.51</td>
#       <td id="T_dafcc_row1_col2" class="data row1 col2" >0.89</td>
#       <td id="T_dafcc_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_dafcc_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_dafcc_row1_col5" class="data row1 col5" >0.99</td>
#       <td id="T_dafcc_row1_col6" class="data row1 col6" >0.98</td>
#       <td id="T_dafcc_row1_col7" class="data row1 col7" >0.77</td>
#       <td id="T_dafcc_row1_col8" class="data row1 col8" >0.95</td>
#       <td id="T_dafcc_row1_col9" class="data row1 col9" >0.67</td>
#     </tr>
#     <tr>
#       <td id="T_dafcc_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T_dafcc_row2_col1" class="data row2 col1" >0.28</td>
#       <td id="T_dafcc_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_dafcc_row2_col3" class="data row2 col3" >0.04</td>
#       <td id="T_dafcc_row2_col4" class="data row2 col4" >0.27</td>
#       <td id="T_dafcc_row2_col5" class="data row2 col5" >0.66</td>
#       <td id="T_dafcc_row2_col6" class="data row2 col6" >0.22</td>
#       <td id="T_dafcc_row2_col7" class="data row2 col7" >0.73</td>
#       <td id="T_dafcc_row2_col8" class="data row2 col8" >0.87</td>
#       <td id="T_dafcc_row2_col9" class="data row2 col9" >0.67</td>
#     </tr>
#     <tr>
#       <td id="T_dafcc_row3_col0" class="data row3 col0" >LOF</td>
#       <td id="T_dafcc_row3_col1" class="data row3 col1" >0.16</td>
#       <td id="T_dafcc_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_dafcc_row3_col3" class="data row3 col3" >0.02</td>
#       <td id="T_dafcc_row3_col4" class="data row3 col4" >0.38</td>
#       <td id="T_dafcc_row3_col5" class="data row3 col5" >0.28</td>
#       <td id="T_dafcc_row3_col6" class="data row3 col6" >0.14</td>
#       <td id="T_dafcc_row3_col7" class="data row3 col7" >0.70</td>
#       <td id="T_dafcc_row3_col8" class="data row3 col8" >0.22</td>
#       <td id="T_dafcc_row3_col9" class="data row3 col9" >0.67</td>
#     </tr>
#     <tr>
#       <td id="T_dafcc_row4_col0" class="data row4 col0" >MCD</td>
#       <td id="T_dafcc_row4_col1" class="data row4 col1" >0.41</td>
#       <td id="T_dafcc_row4_col2" class="data row4 col2" >0.86</td>
#       <td id="T_dafcc_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_dafcc_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_dafcc_row4_col5" class="data row4 col5" >1.00</td>
#       <td id="T_dafcc_row4_col6" class="data row4 col6" >0.96</td>
#       <td id="T_dafcc_row4_col7" class="data row4 col7" >0.77</td>
#       <td id="T_dafcc_row4_col8" class="data row4 col8" >0.96</td>
#       <td id="T_dafcc_row4_col9" class="data row4 col9" >0.67</td>
#     </tr>
#     <tr>
#       <td id="T_dafcc_row5_col0" class="data row5 col0" >OCSVM</td>
#       <td id="T_dafcc_row5_col1" class="data row5 col1" >0.52</td>
#       <td id="T_dafcc_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_dafcc_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_dafcc_row5_col4" class="data row5 col4" >1.00</td>
#       <td id="T_dafcc_row5_col5" class="data row5 col5" >0.99</td>
#       <td id="T_dafcc_row5_col6" class="data row5 col6" >0.97</td>
#       <td id="T_dafcc_row5_col7" class="data row5 col7" >0.77</td>
#       <td id="T_dafcc_row5_col8" class="data row5 col8" >0.87</td>
#       <td id="T_dafcc_row5_col9" class="data row5 col9" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_dafcc_row6_col0" class="data row6 col0" >Perception</td>
#       <td id="T_dafcc_row6_col1" class="data row6 col1" >0.37</td>
#       <td id="T_dafcc_row6_col2" class="data row6 col2" >0.88</td>
#       <td id="T_dafcc_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_dafcc_row6_col4" class="data row6 col4" >1.00</td>
#       <td id="T_dafcc_row6_col5" class="data row6 col5" >0.90</td>
#       <td id="T_dafcc_row6_col6" class="data row6 col6" >0.96</td>
#       <td id="T_dafcc_row6_col7" class="data row6 col7" >0.70</td>
#       <td id="T_dafcc_row6_col8" class="data row6 col8" >0.68</td>
#       <td id="T_dafcc_row6_col9" class="data row6 col9" >0.67</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create dataframe for F1-score
df_f1= metrics_df[['Dataset', 'Classifier', 'F1']]
df_f1 = pd.pivot_table(df_f1, values = 'F1', index=['Classifier'], columns='Dataset').reset_index()
df_f1.columns.name = None

cols = [col for col in df_f1.columns]
formatdict = {}
for col in cols: formatdict[col] = "{:.3f}"
formatdict.pop('Classifier', None)

sub = df_f1.columns.values.tolist()
sub.remove('Classifier')
sub

df_f1 = df_f1.style.hide_index().apply(highlight_max, subset=sub).format(formatdict)

img_title = "F1-score results"
path_save = image_save_path + "dataset_f1-score.png"

# dfi.export(df_f1,path_save)

df_f1
# Out:
# <style type="text/css">
# #T_95aa7_row4_col8, #T_95aa7_row5_col1, #T_95aa7_row6_col2, #T_95aa7_row6_col3, #T_95aa7_row6_col4, #T_95aa7_row6_col5, #T_95aa7_row6_col6, #T_95aa7_row6_col7, #T_95aa7_row6_col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_95aa7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Classifier</th>
#       <th class="col_heading level0 col1" >cardio</th>
#       <th class="col_heading level0 col2" >credit-card</th>
#       <th class="col_heading level0 col3" >http</th>
#       <th class="col_heading level0 col4" >musk</th>
#       <th class="col_heading level0 col5" >satimage-2</th>
#       <th class="col_heading level0 col6" >shuttle</th>
#       <th class="col_heading level0 col7" >smtp</th>
#       <th class="col_heading level0 col8" >thyroid</th>
#       <th class="col_heading level0 col9" >wbc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_95aa7_row0_col0" class="data row0 col0" >HBOS</td>
#       <td id="T_95aa7_row0_col1" class="data row0 col1" >0.451</td>
#       <td id="T_95aa7_row0_col2" class="data row0 col2" >0.030</td>
#       <td id="T_95aa7_row0_col3" class="data row0 col3" >0.097</td>
#       <td id="T_95aa7_row0_col4" class="data row0 col4" >0.480</td>
#       <td id="T_95aa7_row0_col5" class="data row0 col5" >0.202</td>
#       <td id="T_95aa7_row0_col6" class="data row0 col6" >0.801</td>
#       <td id="T_95aa7_row0_col7" class="data row0 col7" >0.005</td>
#       <td id="T_95aa7_row0_col8" class="data row0 col8" >0.323</td>
#       <td id="T_95aa7_row0_col9" class="data row0 col9" >0.542</td>
#     </tr>
#     <tr>
#       <td id="T_95aa7_row1_col0" class="data row1 col0" >IForest</td>
#       <td id="T_95aa7_row1_col1" class="data row1 col1" >0.501</td>
#       <td id="T_95aa7_row1_col2" class="data row1 col2" >0.030</td>
#       <td id="T_95aa7_row1_col3" class="data row1 col3" >0.075</td>
#       <td id="T_95aa7_row1_col4" class="data row1 col4" >0.480</td>
#       <td id="T_95aa7_row1_col5" class="data row1 col5" >0.215</td>
#       <td id="T_95aa7_row1_col6" class="data row1 col6" >0.820</td>
#       <td id="T_95aa7_row1_col7" class="data row1 col7" >0.005</td>
#       <td id="T_95aa7_row1_col8" class="data row1 col8" >0.374</td>
#       <td id="T_95aa7_row1_col9" class="data row1 col9" >0.475</td>
#     </tr>
#     <tr>
#       <td id="T_95aa7_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T
#       <td id="T_95aa7_row6_col4" class="data row6 col4" >0.942</td>
#       <td id="T_95aa7_row6_col5" class="data row6 col5" >0.487</td>
#       <td id="T_95aa7_row6_col6" class="data row6 col6" >0.931</td>
#       <td id="T_95aa7_row6_col7" class="data row6 col7" >0.012</td>
#       <td id="T_95aa7_row6_col8" class="data row6 col8" >0.362</td>
#       <td id="T_95aa7_row6_col9" class="data row6 col9" >0.560</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create dataframe for Area under ROC curve
df1= metrics_df[['Dataset', 'Classifier', 'AUC']]
df1 = pd.pivot_table(df1, values = 'AUC', index=['Classifier'], columns='Dataset').reset_index()
df1.columns.name = None

cols = [col for col in df1.columns]
formatdict = {}
for col in cols: formatdict[col] = "{:.2f}"
formatdict.pop('Classifier', None)

sub = df1.columns.values.tolist()
sub.remove('Classifier')
sub

df1 = df1.style.hide_index().apply(highlight_max, subset=sub).format(formatdict)

img_title = "F1-score results"
path_save = image_save_path + "dataset_auc.png"

# dfi.export(df1,path_save)

df1
# Out:
# <style type="text/css">
# #T_2c869_row0_col2, #T_2c869_row0_col9, #T_2c869_row1_col3, #T_2c869_row1_col4, #T_2c869_row1_col6, #T_2c869_row4_col4, #T_2c869_row4_col7, #T_2c869_row4_col8, #T_2c869_row5_col1, #T_2c869_row5_col4, #T_2c869_row5_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2c869_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Classifier</th>
#       <th class="col_heading level0 col1" >cardio</th>
#       <th class="col_heading level0 col2" >credit-card</th>
#       <th class="col_heading level0 col3" >http</th>
#       <th class="col_heading level0 col4" >musk</th>
#       <th class="col_heading level0 col5" >satimage-2</th>
#       <th class="col_heading level0 col6" >shuttle</th>
#       <th class="col_heading level0 col7" >smtp</th>
#       <th class="col_heading level0 col8" >thyroid</th>
#       <th class="col_heading level0 col9" >wbc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c869_row0_col0" class="data row0 col0" >HBOS</td>
#       <td id="T_2c869_row0_col1" class="data row0 col1" >0.85</td>
#       <td id="T_2c869_row0_col2" class="data row0 col2" >0.95</td>
#       <td id="T_2c869_row0_col3" class="data row0 col3" >0.99</td>
#       <td id="T_2c869_row0_col4" class="data row0 col4" >1.00</td>
#       <td id="T_2c869_row0_col5" class="data row0 col5" >0.98</td>
#       <td id="T_2c869_row0_col6" class="data row0 col6" >0.98</td>
#       <td id="T_2c869_row0_col7" class="data row0 col7" >0.80</td>
#       <td id="T_2c869_row0_col8" class="data row0 col8" >0.95</td>
#       <td id="T_2c869_row0_col9" class="data row0 col9" >0.96</td>
#     </tr>
#     <tr>
#       <td id="T_2c869_row1_col0" class="data row1 col0" >IForest</td>
#       <td id="T_2c869_row1_col1" class="data row1 col1" >0.92</td>
#       <td id="T_2c869_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_2c869_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_2c869_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_2c869_row1_col5" class="data row1 col5" >0.99</td>
#       <td id="T_2c869_row1_col6" class="data row1 col6" >1.00</td>
#       <td id="T_2c869_row1_col7" class="data row1 col7" >0.91</td>
#       <td id="T_2c869_row1_col8" class="data row1 col8" >0.98</td>
#       <td id="T_2c869_row1_col9" class="data row1 col9" >0.93</td>
#     </tr>
#     <tr>
#       <td id="T_2c869_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T
td>
#     </tr>
#   </tbody>
# </table>

# %%
# create dataframe for total training and prediction time
df1= metrics_df[['Dataset', 'Classifier', 'Runtime']]
df1 = pd.pivot_table(df1, values = 'Runtime', index=['Classifier'], columns='Dataset').reset_index()
df1.columns.name = None

cols = [col for col in df1.columns]
formatdict = {}
for col in cols: formatdict[col] = "{:.4f}"
formatdict.pop('Classifier', None)

sub = df1.columns.values.tolist()
sub.remove('Classifier')
sub

df1 = df1.style.hide_index().apply(highlight_min, subset=sub).format(formatdict)

path_save = image_save_path + "dataset_total_time.png"

# dfi.export(df1,path_save)

df1
# Out:
# <style type="text/css">
# #T_d341e_row0_col3, #T_d341e_row0_col6, #T_d341e_row0_col7, #T_d341e_row6_col1, #T_d341e_row6_col2, #T_d341e_row6_col4, #T_d341e_row6_col5, #T_d341e_row6_col8, #T_d341e_row6_col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d341e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Classifier</th>
#       <th class="col_heading level0 col1" >cardio</th>
#       <th class="col_heading level0 col2" >credit-card</th>
#       <th class="col_heading level0 col3" >http</th>
#       <th class="col_heading level0 col4" >musk</th>
#       <th class="col_heading level0 col5" >satimage-2</th>
#       <th class="col_heading level0 col6" >shuttle</th>
#       <th class="col_heading level0 col7" >smtp</th>
#       <th class="col_heading level0 col8" >thyroid</th>
#       <th class="col_heading level0 col9" >wbc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d341e_row0_col0" class="data row0 col0" >HBOS</td>
#       <td id="T_d341e_row0_col1" class="data row0 col1" >0.0081</td>
#       <td id="T_d341e_row0_col2" class="data row0 col2" >0.5205</td>
#       <td id="T_d341e_row0_col3" class="data row0 col3" >0.1255</td>
#       <td id="T_d341e_row0_col4" class="data row0 col4" >0.0603</td>
#       <td id="T_d341e_row0_col5" class="data row0 col5" >0.0207</td>
#       <td id="T_d341e_row0_col6" class="data row0 col6" >0.0256</td>
#       <td id="T_d341e_row0_col7" class="data row0 col7" >0.0305</td>
#       <td id="T_d341e_row0_col8" class="data row0 col8" >0.0055</td>
#       <td id="T_d341e_row0_col9" class="data row0 col9" >0.0068</td>
#     </tr>
#     <tr>
#       <td id="T_d341e_row1_col0" class="data row1 col0" >IForest</td>
#       <td id="T_d341e_row1_col1" class="data row1 col1" >0.3935</td>
#       <td id="T_d341e_row1_col2" class="data row1 col2" >34.0882</td>
#       <td id="T_d341e_row1_col3" class="data row1 col3" >45.5052</td>
#       <td id="T_d341e_row1_col4" class="data row1 col4" >1.1002</td>
#       <td id="T_d341e_row1_col5" class="data row1 col5" >1.0373</td>
#       <td id="T_d341e_row1_col6" class="data row1 col6" >4.4627</td>
#       <td id="T_d341e_row1_col7" class="data row1 col7" >8.1956</td>
#       <td id="T_d341e_row1_col8" class="data row1 col8" >0.5356</td>
#       <td id="T_d341e_row1_col9" class="data row1 col9" >0.3172</td>
#     </tr>
#     <tr>
#       <td id="T_d341e_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T_d341e_row2_col1" class="data row2 col1" >0.4118</td>
#       <td id="T_d341e_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_d341e_row2_col3" class="data row2 col3" >80.4057</td>
#       <td id="T_d341e_row2_col4" class="data row2 col4" >3.2900</td>
#       <td id="T_d341e_row2_col5" class="data row2 col5" >2.4352</td>
#       <td id="T_d341e_row2_col6" class="data row2 col6" >17.3416</td>
#       <td id="T_d341e_row2_col7" class="data row2 col7" >11.1426</td>
#       <td id="T_d341e_row2_col8" class="data row2 col8" >0.5136</td>
#       <td id="T_d341e_row2_col9" class="data row2 col9" >0.0480</td>
#     </tr>
#     <tr>
#       <td id="T_d341e_row3_col0" class="data row3 col0" >LOF</td>
#       <td id="T_d341e_row3_col1" class="data row3 col1" >0.1521</td>
#       <td id="T_d341e_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_d341e_row3_col3" class="data row3 col3" >30.4202</td>
#       <td id="T_d341e_row3_col4" class="data row3 col4" >0.4230</td>
#       <td id="T_d341e_row3_col5" class="data row3 col5" >1.4590</td>
#       <td id="T_d341e_row3_col6" class="data row3 col6" >25.0287</td>
#       <td id="T_d341e_row3_col7" class="data row3 col7" >2.4765</td>
#       <td id="T_d341e_row3_col8" class="data row3 col8" >0.2558</td>
#       <td id="T_d341e_row3_col9" class="data row3 col9" >0.0122</td>
#     </tr>
#     <tr>
#       <td id="T_d341e_row4_col0" class="data row4 col0" >MCD</td>
#       <td id="T_d341e_row4_col1" class="data row4 col1" >0.4746</td>
#       <td id="T_d341e_row4_col2" class="data row4 col2" >34.4583</td>
#       <td id="T_d341e_row4_col3" class="data row4 col3" >41.3554</td>
#       <td id="T_d341e_row4_col4" class="data row4 col4" >7.3165</td>
#       <td id="T_d341e_row4_col5" class="data row4 col5" >2.5087</td>
#       <td id="T_d341e_row4_col6" class="data row4 col6" >14.9477</td>
#       <td id="T_d341e_row4_col7" class="data row4 col7" >15.8166</td>
#       <td id="T_d341e_row4_col8" class="data row4 col8" >1.0661</td>
#       <td id="T_d341e_row4_col9" class="data row4 col9" >0.1439</td>
#     </tr>
#     <tr>
#       <td id="T_d341e_row5_col0" class="data row5 col0" >OCSVM</td>
#       <td id="T_d341e_row5_col1" class="data row5 col1" >0.6214</td>
#       <td id="T_d341e_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_d341e_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_d341e_row5_col4" class="data row5 col4" >2.3988</td>
#       <td id="T_d341e_row5_col5" class="data row5 col5" >7.7187</td>
#       <td id="T_d341e_row5_col6" class="data row5 col6" >408.2622</td>
#       <td id="T_d341e_row5_col7" class="data row5 col7" >1528.2898</td>
#       <td id="T_d341e_row5_col8" class="data row5 col8" >2.1341</td>
#       <td id="T_d341e_row5_col9" class="data row5 col9" >0.0263</td>
#     </tr>
#     <tr>
#       <td id="T_d341e_row6_col0" class="data row6 col0" >Perception</td>
#       <td id="T_d341e_row6_col1" class="data row6 col1" >0.0025</td>
#       <td id="T_d341e_row6_col2" class="data row6 col2" >0.4016</td>
#       <td id="T_d341e_row6_col3" class="data row6 col3" >0.5524</td>
#       <td id="T_d341e_row6_col4" class="data row6 col4" >0.0102</td>
#       <td id="T_d341e_row6_col5" class="data row6 col5" >0.0078</td>
#       <td id="T_d341e_row6_col6" class="data row6 col6" >0.0472</td>
#       <td id="T_d341e_row6_col7" class="data row6 col7" >0.0892</td>
#       <td id="T_d341e_row6_col8" class="data row6 col8" >0.0039</td>
#       <td id="T_d341e_row6_col9" class="data row6 col9" >0.0015</td>
#     </tr>
#   </tbody>
# </table>
